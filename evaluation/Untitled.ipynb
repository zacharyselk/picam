# %%
import os
import sys

# Only way to import with a relitive path
sys.path.append(os.path.join(os.path.dirname('__file__'), '..', 'scripts'))
import analysis_tools as tools

# %%
LOGS_PATH = '../logs/'

# %%
obj = tools.evaluate([LOGS_PATH + '1800sec_120fps_480p.5.h264.ts', 
                      LOGS_PATH + '1800sec_120fps_480p.yuv.ts',
                      LOGS_PATH + '1800sec_120fps_480p.mjpeg.ts'
                     ])
obj.x_size = 15
obj.y_size = 10
obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 1800sec_120fps_480p.5.h264
#   Sec: 1799.929452
#   Frames: 216966
#   Framerate: 120.54139108558793
#   Standard Deviation: 0.563629 µs
#
#
# 1800sec_120fps_480p.yuv
#   Sec: 1799.9457909999999
#   Frames: 35072
#   Framerate: 19.48503125781081
#   Standard Deviation: 6.165113 sec
#
#
# 1800sec_120fps_480p.mjpeg
#   Sec: 1799.9707139999998
#   Frames: 204798
#   Framerate: 113.77851784315199
#   Standard Deviation: 31.296858 ms

# %%
# Max for 1080p
obj = tools.evaluate([LOGS_PATH + '1800sec_120fps_480p.3.h264.ts',
                      LOGS_PATH + '1800sec_120fps_480p.4.h264.ts',
                      LOGS_PATH + '1800sec_120fps_480p.5.h264.ts'
                     ])

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 1800sec_120fps_480p.3.h264
#   Sec: 1796.660644
#   Frames: 214704
#   Framerate: 119.50169928695783
#   Standard Deviation: 12.231864 ms
#
#
# 1800sec_120fps_480p.4.h264
#   Sec: 1799.929426
#   Frames: 216966
#   Framerate: 120.54139282680964
#   Standard Deviation: 0.563604 µs
#
#
# 1800sec_120fps_480p.5.h264
#   Sec: 1799.929452
#   Frames: 216966
#   Framerate: 120.54139108558793
#   Standard Deviation: 0.563629 µs

# %%
obj = tools.evaluate(LOGS_PATH + '100sec_30fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 100sec_30fps_720p_inet.h264
#   Sec: 99.715337
#   Frames: 2992
#   Framerate: 30.00541431254452
#   Standard Deviation: 19.260910 µs

# %%
obj = tools.evaluate(LOGS_PATH + '500sec_30fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 500sec_30fps_720p_inet.h264
#   Sec: 499.710084
#   Frames: 14994
#   Framerate: 30.005398089985313
#   Standard Deviation: 8.606464 µs

# %%
obj = tools.evaluate(LOGS_PATH + '100sec_40fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 100sec_40fps_720p_inet.h264
#   Sec: 0.474823
#   Frames: 19
#   Framerate: 40.01491081940007
#   Standard Deviation: 5.446594 ms

# %%
obj = tools.evaluate([LOGS_PATH + '900sec_120fps_480p_singlerecord.h264.ts',
                      LOGS_PATH + '900sec_120fps_480p_singlerecord_bash.h264.ts',
                      LOGS_PATH + '900sec_120fps_480p_singlerecord_python.h264.ts',
                      LOGS_PATH + '900sec_120fps_480p_singlerecord_cc.h264.ts'
                     ])

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 900sec_120fps_480p_singlerecord.h264
#   Sec: 899.97261
#   Frames: 108484
#   Framerate: 120.54144625579215
#   Standard Deviation: 0.798376 µs
#
#
# 900sec_120fps_480p_singlerecord_bash.h264
#   Sec: 899.9644949999999
#   Frames: 101726
#   Framerate: 113.03334805446964
#   Standard Deviation: 1.178769 sec
#
#
# 900sec_120fps_480p_singlerecord_python.h264
#   Sec: 899.97266
#   Frames: 102398
#   Framerate: 113.7790119090951
#   Standard Deviation: 1.035707 sec
#
#
# 900sec_120fps_480p_singlerecord_cc.h264
#   Sec: 899.972759
#   Frames: 105285
#   Framerate: 116.98687426604654
#   Standard Deviation: 22.444209 ms

# %%
obj = tools.evaluate([LOGS_PATH + '500sec_120fps_480p_nowrite.yuv.ts',
                      LOGS_PATH + '500sec_120fps_480p_nowrite.bgr.ts',
                      LOGS_PATH + '500sec_90fps_480p_nowrite.bgr.ts',
                      LOGS_PATH + '500sec_60fps_480p_nowrite.bgr.ts',
                      LOGS_PATH + '500sec_30fps_480p_nowrite.bgr.ts'
                     ])

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 500sec_120fps_480p_nowrite.yuv
#   Sec: 499.877979
#   Frames: 58786
#   Framerate: 117.60069950990982
#   Standard Deviation: 2.771356 ms
#
#
# 500sec_120fps_480p_nowrite.bgr
#   Sec: 499.861472
#   Frames: 30697
#   Framerate: 61.41101428997513
#   Standard Deviation: 4.296369 ms
#
#
# 500sec_90fps_480p_nowrite.bgr
#   Sec: 499.81603
#   Frames: 38066
#   Framerate: 76.16002231861191
#   Standard Deviation: 4.685383 ms
#
#
# 500sec_60fps_480p_nowrite.bgr
#   Sec: 499.73370500000004
#   Frames: 30067
#   Framerate: 60.166043833285165
#   Standard Deviation: 1.631336 ms
#
#
# 500sec_30fps_480p_nowrite.bgr
#   Sec: 499.71036300000003
#   Frames: 14994
#   Framerate: 30.005381337268762
#   Standard Deviation: 8.606627 µs

# %%
obj = tools.evaluate([LOGS_PATH + '500sec_60fps_480p_nowrite.bgr.ts',
                      LOGS_PATH + '500sec_45fps_480p_nowrite.bgr.ts',
                      LOGS_PATH + '500sec_30fps_480p_nowrite.bgr.ts'
                     ])

obj.info()
obj.dropped_frames()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 500sec_60fps_480p_nowrite.bgr
#   Sec: 499.73370500000004
#   Frames: 30067
#   Framerate: 60.166043833285165
#   Standard Deviation: 1.631336 ms
#
#
# 500sec_45fps_480p_nowrite.bgr
#   Sec: 499.827039
#   Frames: 22554
#   Framerate: 45.12360924915869
#   Standard Deviation: 4.666476 µs
#
#
# 500sec_30fps_480p_nowrite.bgr
#   Sec: 499.71036300000003
#   Frames: 14994
#   Framerate: 30.005381337268762
#   Standard Deviation: 8.606627 µs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-927057b503c7> in <module>()
#       5
#       6 obj.info()
# ----> 7 obj.dropped_frames()
#       8 obj.plot_framerate()
#       9 obj.plot_relative_deviation()
#
# AttributeError: 'evaluate' object has no attribute 'dropped_frames'
