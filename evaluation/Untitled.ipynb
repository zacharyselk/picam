# %%
import os
import sys

# Only way to import with a relitive path
sys.path.append(os.path.join(os.path.dirname('__file__'), '..', 'scripts'))
import analysis_tools as tools

# %%
LOGS_PATH = '../logs/'

# %%
obj = tools.fileEvaluation(LOGS_PATH + '100sec_120fps_inet_notnice.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# Sec: 99.882622
# Frames: 12040
# Framerate: 120.5414891891805
# Standard Deviation: 5.717399 µs

# %%
# Max for 1080p
obj = tools.fileEvaluation(LOGS_PATH + '100sec_5fps_full1080p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# Sec: 92.392043
# Frames: 453
# Framerate: 4.90301962475275
# Standard Deviation: 868.487493 ms

# %%
obj = tools.fileEvaluation(LOGS_PATH + '100sec_30fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# Sec: 99.715337
# Frames: 2992
# Framerate: 30.00541431254452
# Standard Deviation: 370.982648 µs

# %%
obj = tools.fileEvaluation(LOGS_PATH + '500sec_30fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# Sec: 499.710084
# Frames: 14994
# Framerate: 30.005398089985313
# Standard Deviation: 74.071223 µs

# %%
obj = tools.fileEvaluation(LOGS_PATH + '100sec_40fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# Sec: 0.474823
# Frames: 19
# Framerate: 40.01491081940007
# Standard Deviation: 29.665384 ms

# %%
obj = tools.fileEvaluation(LOGS_PATH + '100sec_40fps.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-ea6c1ddbb3a4> in <module>()
# ----> 1 obj = tools.fileEvaluation(LOGS_PATH + '100sec_40fps.h264.ts')
#       2
#       3 obj.info()
#       4 obj.plot_framerate()
#       5 obj.plot_relative_deviation()
#
# ~/coding/git/picam/scripts/analysis_tools.py in __init__(self, ts_path_name, target_fps)
#      13         self.standard_deviation = u''
#      14
# ---> 15         with open(self.file_path, 'r') as f:
#      16             self.lines = f.readlines()
#      17         self.find_framerate()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../logs/100sec_40fps.h264.ts'

# %%
# Four axes, returned as a 2-d array
f, axarr = plt.subplots(2, 2)
axarr[0, 0].plot(x, y)
axarr[0, 0].set_title('Axis [0,0]')
axarr[0, 1].scatter(x, y)
axarr[0, 1].set_title('Axis [0,1]')
axarr[1, 0].plot(x, y ** 2)
axarr[1, 0].set_title('Axis [1,0]')
axarr[1, 1].scatter(x, y ** 2)
axarr[1, 1].set_title('Axis [1,1]')
# Fine-tune figure; hide x ticks for top plots and y ticks for right plots
#plt.setp([a.get_xticklabels() for a in axarr[0, :]], visible=False)
#plt.setp([a.get_yticklabels() for a in axarr[:, 1]], visible=False)
