# %%
import os
import sys

# Only way to import with a relitive path
sys.path.append(os.path.join(os.path.dirname('__file__'), '..', 'scripts'))
import analysis_tools as tools

# %%
LOGS_PATH = '../logs/'

# %%
obj = tools.evaluate([LOGS_PATH + '900sec_120fps_480p.h264.ts', 
                      LOGS_PATH + '900sec_120fps_480p.mjpeg.ts',
                      LOGS_PATH + '900sec_120fps_480p.yuv.ts'
                     ])
obj.x_size = 15
obj.y_size = 10
obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 900sec_120fps_480p.h264
#   Sec: 899.9644300000001
#   Frames: 103629
#   Framerate: 115.14788423360243
#   Standard Deviation: 27.954440 ms
#
#
# 900sec_120fps_480p.mjpeg
#   Sec: 899.9725579999999
#   Frames: 108484
#   Framerate: 120.54145322062143
#   Standard Deviation: 0.796840 µs
#
#
# 900sec_120fps_480p.yuv
#   Sec: 899.889773
#   Frames: 108474
#   Framerate: 120.54142991132758
#   Standard Deviation: 0.796827 µs

# %%
# Max for 1080p
obj = tools.fileEvaluation(LOGS_PATH + '100sec_5fps_full1080p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ebdf34e101ad> in <module>()
#       1 # Max for 1080p
# ----> 2 obj = tools.fileEvaluation(LOGS_PATH + '100sec_5fps_full1080p_inet.h264.ts')
#       3
#       4 obj.info()
#       5 obj.plot_framerate()
#
# AttributeError: module 'analysis_tools' has no attribute 'fileEvaluation'

# %%
obj = tools.fileEvaluation(LOGS_PATH + '100sec_30fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()

# %%
obj = tools.fileEvaluation(LOGS_PATH + '500sec_30fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()

# %%
obj = tools.fileEvaluation(LOGS_PATH + '100sec_40fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()

# %%
obj = tools.fileEvaluation(LOGS_PATH + '100sec_40fps.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()

# %%
# Four axes, returned as a 2-d array
f, axarr = plt.subplots(2, 2)
axarr[0, 0].plot(x, y)
axarr[0, 0].set_title('Axis [0,0]')
axarr[0, 1].scatter(x, y)
axarr[0, 1].set_title('Axis [0,1]')
axarr[1, 0].plot(x, y ** 2)
axarr[1, 0].set_title('Axis [1,0]')
axarr[1, 1].scatter(x, y ** 2)
axarr[1, 1].set_title('Axis [1,1]')
# Fine-tune figure; hide x ticks for top plots and y ticks for right plots
#plt.setp([a.get_xticklabels() for a in axarr[0, :]], visible=False)
#plt.setp([a.get_yticklabels() for a in axarr[:, 1]], visible=False)
