# %%
import os
import sys

# Only way to import with a relitive path
sys.path.append(os.path.join(os.path.dirname('__file__'), '..', 'scripts'))
import analysis_tools as tools

# %%
LOGS_PATH = '../logs/'

# %%
obj = tools.evaluate([LOGS_PATH + '900sec_120fps_480p.h264.ts', 
                      LOGS_PATH + '900sec_120fps_480p.mjpeg.ts',
                      LOGS_PATH + '900sec_120fps_480p.yuv.ts'
                     ])
obj.x_size = 15
obj.y_size = 10
obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 900sec_120fps_480p.h264
#   Sec: 899.9644300000001
#   Frames: 103629
#   Framerate: 115.14788423360243
#   Standard Deviation: 27.954440 ms
#
#
# 900sec_120fps_480p.mjpeg
#   Sec: 899.9725579999999
#   Frames: 108484
#   Framerate: 120.54145322062143
#   Standard Deviation: 0.796840 µs
#
#
# 900sec_120fps_480p.yuv
#   Sec: 899.889773
#   Frames: 108474
#   Framerate: 120.54142991132758
#   Standard Deviation: 0.796827 µs

# %%
# Max for 1080p
obj = tools.evaluate(LOGS_PATH + '100sec_5fps_full1080p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 100sec_5fps_full1080p_inet.h264
#   Sec: 92.392043
#   Frames: 453
#   Framerate: 4.90301962475275
#   Standard Deviation: 29.470112 ms

# %%
obj = tools.evaluate(LOGS_PATH + '100sec_30fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 100sec_30fps_720p_inet.h264
#   Sec: 99.715337
#   Frames: 2992
#   Framerate: 30.00541431254452
#   Standard Deviation: 19.260910 µs

# %%
obj = tools.evaluate(LOGS_PATH + '500sec_30fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 500sec_30fps_720p_inet.h264
#   Sec: 499.710084
#   Frames: 14994
#   Framerate: 30.005398089985313
#   Standard Deviation: 8.606464 µs

# %%
obj = tools.evaluate(LOGS_PATH + '100sec_40fps_720p_inet.h264.ts')

obj.info()
obj.plot_framerate()
obj.plot_relative_deviation()
obj.plot_timestamps()
# Out:
# 100sec_40fps_720p_inet.h264
#   Sec: 0.474823
#   Frames: 19
#   Framerate: 40.01491081940007
#   Standard Deviation: 5.446594 ms
